# %%
import pandas as pd

# %%
import numpy as np

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Loan_Defaulter.csv")

# %%
df.head()
# Out:
#          ID Client_Income  Car_Owned  Bike_Owned  Active_Loan  House_Own  \
# 0  12142509          6750        0.0         0.0          1.0        0.0
# 1  12138936         20250        1.0         0.0          1.0        NaN
# 2  12181264         18000        0.0         0.0          1.0        0.0
# 3  12188929         15750        0.0         0.0          1.0        1.0
# 4  12133385         33750        1.0         0.0          1.0        0.0
#
#    Child_Count Credit_Amount Loan_Annuity Accompany_Client  ...  \
# 0          0.0      61190.55      3416.85            Alone  ...
# 1          0.0         15282      1826.55            Alone  ...
# 2          1.0      59527.35       2788.2            Alone  ...
# 3          0.0       53870.4      2295.45            Alone  ...
# 4          2.0      133988.4      3547.35            Alone  ...
#
#   Client_Permanent_Match_Tag Client_Contact_Work_Tag       Type_Organization  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Client_Income', 'Car_Owned', 'Bike_Owned', 'Active_Loan',
#        'House_Own', 'Child_Count', 'Credit_Amount', 'Loan_Annuity',
#        'Accompany_Client', 'Client_Income_Type', 'Client_Education',
#        'Client_Marital_Status', 'Client_Gender', 'Loan_Contract_Type',
#        'Client_Housing_Type', 'Population_Region_Relative', 'Age_Days',
#        'Employed_Days', 'Registration_Days', 'ID_Days', 'Own_House_Age',
#        'Mobile_Tag', 'Homephone_Tag', 'Workphone_Working', 'Client_Occupation',
#        'Client_Family_Members', 'Cleint_City_Rating',
#        'Application_Process_Day', 'Application_Process_Hour',
#        'Client_Permanent_Match_Tag', 'Client_Contact_Work_Tag',
#        'Type_Organization', 'Score_Source_1', 'Score_Source_2',
#        'Score_Source_3', 'Social_Circle_Default', 'Phone_Change',
#        'Credit_Bureau', 'Default'],
#       dtype='object')

# %%
df.corr()
# Out:
#                                 ID  Car_Owned  Bike_Owned  Active_Loan  \
# ID                        1.000000  -0.003510   -0.001487    -0.000836
# Car_Owned                -0.003510   1.000000   -0.000409    -0.001577
# Bike_Owned               -0.001487  -0.000409    1.000000     0.001545
# Active_Loan              -0.000836  -0.001577    0.001545     1.000000
# House_Own                 0.000588  -0.008344    0.002125    -0.005709
# Child_Count              -0.008734   0.100579    0.002209     0.001789
# Own_House_Age             0.003739        NaN    0.005183    -0.005846
# Mobile_Tag               -0.002055  -0.004026   -0.004123     0.002904
# Homephone_Tag            -0.005787   0.011443   -0.002272     0.001333
# Workphone_Working         0.003871  -0.008597   -0.005849     0.000222
# Client_Family_Members    -0.006603   0.148582    0.003196    -0.000822
# Cleint_City_Rating       -0.002193  -0.022454    0.000219    -0.002666
# ...

# %%
df.shape
# Out:
# (121856, 40)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               118249 non-null  object
#  2   Car_Owned                   118275 non-null  float64
#  3   Bike_Owned                  118232 non-null  float64
#  4   Active_Loan                 118221 non-null  float64
#  5   House_Own                   118195 non-null  float64
#  6   Child_Count                 118218 non-null  float64
#  7   Credit_Amount               118224 non-null  object
#  8   Loan_Annuity                117044 non-null  object
#  9   Accompany_Client            120110 non-null  object
#  10  Client_Income_Type          118155 non-null  object
#  11  Client_Education            118211 non-null  object
# ...

# %%
pd.set_option('display.max_rows',None)

# %%
df.isna().apply(pd.value_counts).T
# Out:
#                                False     True
# ID                          121856.0      NaN
# Client_Income               118249.0   3607.0
# Car_Owned                   118275.0   3581.0
# Bike_Owned                  118232.0   3624.0
# Active_Loan                 118221.0   3635.0
# House_Own                   118195.0   3661.0
# Child_Count                 118218.0   3638.0
# Credit_Amount               118224.0   3632.0
# Loan_Annuity                117044.0   4812.0
# Accompany_Client            120110.0   1746.0
# Client_Income_Type          118155.0   3701.0
# Client_Education            118211.0   3645.0
# Client_Marital_Status       118383.0   3473.0
# Client_Gender               119443.0   2413.0
# Loan_Contract_Type          118205.0   3651.0
# Client_Housing_Type         118169.0   3687.0
# Population_Region_Relative  116999.0   4857.0
# Age_Days                    118256.0   3600.0
# Employed_Days               118207.0   3649.0
# ...

# %%
df['Client_Income'].value_counts()
# Out:
# 13500         11908
# 11250         10302
# 15750          8719
# 18000          8215
# 9000           7577
# 22500          6927
# 20250          5460
# 27000          3624
# 6750           3623
# 8100           2025
# 31500          1979
# 13500.0        1809
# 24750          1731
# 11250.0        1638
# 12600          1531
# 15750.0        1427
# 36000          1314
# 18000.0        1299
# 12150          1253
# 9900           1236
# 9000.0         1128
# 29250          1118
# 10350          1072
# 22500.0        1048
# 14400          1043
# 7650           1008
# 11700           875
# 20250.0         849
# 45000           844
# 17100           811
# 5400            791
# 7200            736
# 4500            691
# 16650           690
# 10800           641
# 9450            620
# 18900           613
# 33750           596
# 6750.0          567
# 16200           552
# 40500           548
# 27000.0         523
# 8550            497
# 14850           489
# 21600           469
# ...

# %%
df.isna().sum()
# Out:
# ID                                0
# Client_Income                  3607
# Car_Owned                      3581
# Bike_Owned                     3624
# Active_Loan                    3635
# House_Own                      3661
# Child_Count                    3638
# Credit_Amount                  3632
# Loan_Annuity                   4812
# Accompany_Client               1746
# Client_Income_Type             3701
# Client_Education               3645
# Client_Marital_Status          3473
# Client_Gender                  2413
# Loan_Contract_Type             3651
# Client_Housing_Type            3687
# Population_Region_Relative     4857
# Age_Days                       3600
# Employed_Days                  3649
# Registration_Days              3614
# ID_Days                        5968
# Own_House_Age                 80095
# Mobile_Tag                        0
# Homephone_Tag                     0
# Workphone_Working                 0
# Client_Occupation             41435
# ...

# %%
df['Client_Income']=df['Client_Income'].replace('$',np.nan).astype('float')

# %%
df['Client_Income'].fillna(df['Client_Income'].median(),inplace=True)

# %%
df['Client_Income'].value_counts()
# Out:
# 1.350000e+04    13717
# 1.125000e+04    11940
# 1.575000e+04    10146
# 1.800000e+04     9514
# 9.000000e+03     8705
# 2.250000e+04     7975
# 2.025000e+04     6309
# 1.440000e+04     4833
# 6.750000e+03     4190
# 2.700000e+04     4147
# 8.100000e+03     2323
# 3.150000e+04     2296
# 2.475000e+04     1995
# 1.260000e+04     1776
# 3.600000e+04     1522
# 1.215000e+04     1448
# 9.900000e+03     1433
# 2.925000e+04     1289
# 1.035000e+04     1236
# 7.650000e+03     1153
# 1.170000e+04      987
# 4.500000e+04      966
# 1.710000e+04      938
# 5.400000e+03      923
# 7.200000e+03      844
# 1.665000e+04      808
# 4.500000e+03      774
# 1.080000e+04      758
# 1.890000e+04      703
# 9.450000e+03      696
# 3.375000e+04      694
# 1.620000e+04      645
# 4.050000e+04      639
# 1.485000e+04      582
# 8.550000e+03      574
# 2.160000e+04      531
# 1.305000e+04      459
# 5.850000e+03      454
# 6.300000e+03      435
# 1.935000e+04      401
# 2.115000e+04      390
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   118275 non-null  float64
#  3   Bike_Owned                  118232 non-null  float64
#  4   Active_Loan                 118221 non-null  float64
#  5   House_Own                   118195 non-null  float64
#  6   Child_Count                 118218 non-null  float64
#  7   Credit_Amount               118224 non-null  object
#  8   Loan_Annuity                117044 non-null  object
#  9   Accompany_Client            120110 non-null  object
#  10  Client_Income_Type          118155 non-null  object
#  11  Client_Education            118211 non-null  object
# ...

# %%
df.isna().sum()
# Out:
# ID                                0
# Client_Income                     0
# Car_Owned                      3581
# Bike_Owned                     3624
# Active_Loan                    3635
# House_Own                      3661
# Child_Count                    3638
# Credit_Amount                  3632
# Loan_Annuity                   4812
# Accompany_Client               1746
# Client_Income_Type             3701
# Client_Education               3645
# Client_Marital_Status          3473
# Client_Gender                  2413
# Loan_Contract_Type             3651
# Client_Housing_Type            3687
# Population_Region_Relative     4857
# Age_Days                       3600
# Employed_Days                  3649
# Registration_Days              3614
# ID_Days                        5968
# Own_House_Age                 80095
# Mobile_Tag                        0
# Homephone_Tag                     0
# Workphone_Working                 0
# Client_Occupation             41435
# ...

# %%
df['Car_Owned'].fillna(df['Car_Owned'].median(),inplace=True)

# %%
df['Bike_Owned'].fillna(df['Bike_Owned'].median(),inplace=True)

# %%
df['Active_Loan'].fillna(df['Active_Loan'].median(),inplace=True)

# %%
df['House_Own'].fillna(df['House_Own'].median(),inplace=True)

# %%
df['Child_Count'].fillna(df['Child_Count'].median(),inplace=True)

# %%
df['Credit_Amount'].value_counts()
# Out:
# 45000.0      2513
# 67500.0      2340
# 22500.0      2090
# 27000.0      1865
# 18000.0      1847
# 90000.0      1624
# 45000        1220
# 54504.0      1186
# 25470.0      1159
# 67500        1110
# 80865.0      1053
# 22500        1037
# 13500.0       928
# 18000         914
# 75519.0       911
# 112500.0      894
# 27000         883
# 28440.0       826
# 52128.0       818
# 90000         742
# 107820.0      730
# 128835.0      690
# 45450.0       668
# 26955.0       614
# 25470         600
# 20250.0       593
# 135000.0      588
# 78192.0       581
# 23985.0       567
# 54504         540
# 80865         531
# 64008.0       526
# 31500.0       523
# 24750.0       521
# 100692.0      498
# 112500        471
# 54000.0       461
# 59256.0       458
# 75519         456
# 13500         455
# 36000.0       454
# 50849.55      452
# 83538.0       422
# 49752.0       422
# 28440         410
# 40500.0       404
# 67950.0       399
# 33750.0       396
# 52128         380
# 31410.0       347
# ...

# %%
df['Credit_Amount']=df['Credit_Amount'].replace('$',np.nan).astype('float')
df['Credit_Amount'].fillna(df['Credit_Amount'].median(),inplace=True)

# %%
df['Loan_Annuity'].value_counts()
# Out:
# 900         1885
# 1350        1684
# 675          682
# 1012.5       622
# 3780         504
# 900.0        485
# 2621.7       461
# 1125         448
# 1350.0       407
# 1237.5       399
# 3165.3       389
# 2025         382
# 2250         376
# 2664         366
# 3645.9       346
# 1687.5       344
# 3302.55      294
# 2201.85      272
# 2377.35      265
# 2644.65      251
# 2631.6       250
# 2190.6       248
# 787.5        244
# 2553.75      240
# 2188.8       224
# 3126.15      224
# 4032         204
# 3260.25      204
# 1575         198
# 2700         196
# 2997         193
# 3375         193
# 3052.8       191
# 4500         184
# 2177.55      182
# 1986.75      180
# 3289.5       175
# 1475.1       172
# 1435.05      172
# 4279.05      168
# 2349.45      166
# 675.0        163
# 3163.05      159
# 2608.65      155
# 1012.5       152
# 3007.8       151
# 3152.25      151
# 4533.3       147
# 2393.1       145
# 2650.95      144
# 1396.35      144
# 2493.9       143
# ...

# %%
df['Loan_Annuity']=df['Loan_Annuity'].replace('$',np.nan)
df['Loan_Annuity']=df['Loan_Annuity'].replace('#VALUE!',np.nan).astype('float')
df['Loan_Annuity'].fillna(df['Loan_Annuity'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Accompany_Client            120110 non-null  object
#  10  Client_Income_Type          118155 non-null  object
#  11  Client_Education            118211 non-null  object
# ...

# %%
df.drop(['Accompany_Client'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 39 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Client_Income_Type          118155 non-null  object
#  10  Client_Education            118211 non-null  object
#  11  Client_Marital_Status       118383 non-null  object
# ...

# %%
df.drop(['Client_Income_Type'],axis=1,inplace=True)

# %%
df.drop(['Client_Education'],axis=1,inplace=True)

# %%
df.drop(['Client_Marital_Status'],axis=1,inplace=True)

# %%
df.drop(['Client_Gender'],axis=1,inplace=True)

# %%
df.drop(['Loan_Contract_Type'],axis=1,inplace=True)

# %%
df['Client_Housing_Type'].value_counts()
# Out:
# Home         104870
# Family         5783
# Municipal      4248
# Rental         1816
# Office         1002
# Shared          450
# Name: Client_Housing_Type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Client_Housing_Type']=le.fit_transform(df['Client_Housing_Type'])

# %%
df['Client_Housing_Type'].value_counts()
# Out:
# 1    104870
# 0      5783
# 2      4248
# 6      3687
# 4      1816
# 3      1002
# 5       450
# Name: Client_Housing_Type, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Client_Housing_Type         121856 non-null  int32
#  10  Population_Region_Relative  116999 non-null  object
#  11  Age_Days                    118256 non-null  object
# ...

# %%
df['Client_Housing_Type'].value_counts()
# Out:
# 1    104870
# 0      5783
# 2      4248
# 6      3687
# 4      1816
# 3      1002
# 5       450
# Name: Client_Housing_Type, dtype: int64

# %%
df['Population_Region_Relative'].value_counts()
# Out:
# 0.035792    4159
# 0.04622     3444
# 0.030755    3116
# 0.025164    3017
# 0.026392    2967
# 0.031329    2828
# 0.028663    2815
# 0.072508    2260
# 0.019101    2248
# 0.035792    2108
# 0.020713    2022
# 0.01885     1951
# 0.018634    1831
# 0.022625    1762
# 0.020246    1757
# 0.015221    1746
# 0.032561    1712
# 0.04622     1673
# 0.02461     1604
# 0.018029    1583
# 0.019689    1580
# 0.018209    1566
# 0.030755    1523
# 0.018801    1521
# 0.025164    1499
# 0.031329    1429
# 0.028663    1412
# 0.026392    1363
# 0.01452     1218
# 0.016612    1109
# 0.00702     1086
# 0.019101    1066
# 0.072508    1043
# 0.020713    1023
# 0.0228      1006
# 0.01885      994
# 0.010006     932
# 0.020246     927
# 0.010032     909
# 0.014464     880
# 0.00496      875
# 0.018634     853
# 0.015221     843
# 0.02461      833
# 0.032561     831
# 0.010643     827
# 0.022625     818
# 0.010147     809
# 0.011703     808
# 0.018029     795
# 0.018801     784
# 0.011657     773
# ...

# %%
df.drop(['Population_Region_Relative'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Client_Housing_Type         121856 non-null  int32
#  10  Age_Days                    118256 non-null  object
#  11  Employed_Days               118207 non-null  object
# ...

# %%
df.drop(['Age_Days'],axis=1,inplace=True)
df.drop(['Employed_Days'],axis=1,inplace=True)
df.drop(['Registration_Days'],axis=1,inplace=True)
df.drop(['ID_Days'],axis=1,inplace=True)

df.drop(['Own_House_Age'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (121856, 28)

# %%
df['Client_Occupation'].value_counts()
# Out:
# Laborers              21024
# Sales                 12136
# Core                  10611
# Managers               8099
# Drivers                7150
# High skill tech        4317
# Accountants            3766
# Medicine               3172
# Security               2683
# Cooking                2224
# Cleaning               1722
# Private service        1006
# Low-skill Laborers      787
# Secretaries             531
# Waiters/barmen          511
# Realty agents           280
# HR                      206
# IT                      196
# Name: Client_Occupation, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Client_Occupation']=le.fit_transform(df['Client_Occupation'])

# %%
df['Client_Occupation'].value_counts()
# Out:
# 18    41435
# 8     21024
# 14    12136
# 3     10611
# 10     8099
# 4      7150
# 6      4317
# 0      3766
# 11     3172
# 16     2683
# 2      2224
# 1      1722
# 12     1006
# 9       787
# 15      531
# 17      511
# 13      280
# 5       206
# 7       196
# Name: Client_Occupation, dtype: int64

# %%
correlation = df['Client_Occupation'].corr(df['Default'])

# %%
correlation
# Out:
# -0.01653306721398496

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Client_Housing_Type         121856 non-null  int32
#  10  Mobile_Tag                  121856 non-null  int64
#  11  Homephone_Tag               121856 non-null  int64
# ...

# %%
df['Client_Family_Members'].fillna(df['Client_Family_Members'].median(),inplace=True)
df['Cleint_City_Rating'].fillna(df['Cleint_City_Rating'].median(),inplace=True)

# %%
correlation = df['ID'].corr(df['Default'])

# %%
correlation
# Out:
# 0.00043179325087304345

# %%
df.drop(['Application_Process_Day'],axis=1,inplace=True)
df.drop(['Application_Process_Hour'],axis=1,inplace=True)
df.drop(['Score_Source_1'],axis=1,inplace=True)
df.drop(['Score_Source_2'],axis=1,inplace=True)
df.drop(['Score_Source_3'],axis=1,inplace=True)
df.drop(['Social_Circle_Default'],axis=1,inplace=True)

# %%
df.drop(['Phone_Change'],axis=1,inplace=True)

# %%
df['Credit_Bureau'].fillna(df['Credit_Bureau'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Client_Housing_Type         121856 non-null  int32
#  10  Mobile_Tag                  121856 non-null  int64
#  11  Homephone_Tag               121856 non-null  int64
# ...

# %%
df['Client_Permanent_Match_Tag'].value_counts()
# Out:
# Yes    112454
# No       9402
# Name: Client_Permanent_Match_Tag, dtype: int64

# %%
df['Client_Permanent_Match_Tag']=le.fit_transform(df['Client_Permanent_Match_Tag'])

# %%
df['Client_Permanent_Match_Tag'].value_counts()
# Out:
# 1    112454
# 0      9402
# Name: Client_Permanent_Match_Tag, dtype: int64

# %%
df['Client_Contact_Work_Tag'].value_counts()
# Out:
# Yes    100015
# No      21841
# Name: Client_Contact_Work_Tag, dtype: int64

# %%
df['Client_Contact_Work_Tag']=le.fit_transform(df['Client_Contact_Work_Tag'])

# %%
df['Type_Organization'].value_counts()
# Out:
# Business Entity Type 3    26279
# XNA                       21085
# Self-employed             14725
# Other                      6290
# Medicine                   4320
# Business Entity Type 2     4126
# Government                 3971
# School                     3371
# Trade: type 7              2979
# Kindergarten               2686
# Construction               2623
# Business Entity Type 1     2313
# Transport: type 4          2076
# Trade: type 3              1338
# Security                   1284
# Industry: type 9           1280
# Industry: type 3           1235
# Housing                    1162
# Military                   1031
# Bank                       1012
# Agriculture                1011
# Industry: type 11           999
# Police                      934
# Postal                      834
# Transport: type 2           811
# Security Ministries         756
# Trade: type 2               717
# Restaurant                  710
# Services                    570
# ...

# %%
df['Type_Organization']=le.fit_transform(df['Type_Organization'])

# %%
df['Type_Organization'].fillna(df['Type_Organization'].median(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121856 entries, 0 to 121855
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ID                          121856 non-null  int64
#  1   Client_Income               121856 non-null  float64
#  2   Car_Owned                   121856 non-null  float64
#  3   Bike_Owned                  121856 non-null  float64
#  4   Active_Loan                 121856 non-null  float64
#  5   House_Own                   121856 non-null  float64
#  6   Child_Count                 121856 non-null  float64
#  7   Credit_Amount               121856 non-null  float64
#  8   Loan_Annuity                121856 non-null  float64
#  9   Client_Housing_Type         121856 non-null  int32
#  10  Mobile_Tag                  121856 non-null  int64
#  11  Homephone_Tag               121856 non-null  int64
# ...

# %%
corr=df.corr()

# %% [markdown]
# USING THE VISUALIZATION LIBRARIES

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(55,25))
plt.title('CORRELATIONS',fontsize=25)
sns.heatmap(corr,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#declaring our dependent and independent variables
x=df.drop(['ID','Default'],axis=1)
y=df['Default']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# # LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(x_test,y_test)*100
# Out:
# 91.93746922698179

# %%
#confusion matrix and classification report 
from sklearn.metrics import confusion_matrix,classification_report

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
cf
# Out:
# array([[22407,     0],
#        [ 1965,     0]], dtype=int64)

# %%
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     22407
#            1       0.00      0.00      0.00      1965
#
#     accuracy                           0.92     24372
#    macro avg       0.46      0.50      0.48     24372
# weighted avg       0.85      0.92      0.88     24372

# %% [markdown]
# # K_NEIGHBORS_CLASSIFIER

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier(n_neighbors=2)

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 91.21943213523716

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
cf
# Out:
# array([[22163,   244],
#        [ 1896,    69]], dtype=int64)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95     22407
#            1       0.22      0.04      0.06      1965
#
#     accuracy                           0.91     24372
#    macro avg       0.57      0.51      0.51     24372
# weighted avg       0.86      0.91      0.88     24372

# %% [markdown]
# # NAIVE BAYES CLASSIFIER

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 91.94157229607747

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     22407
#            1       1.00      0.00      0.00      1965
#
#     accuracy                           0.92     24372
#    macro avg       0.96      0.50      0.48     24372
# weighted avg       0.93      0.92      0.88     24372

# %% [markdown]
# # SUPPORT_VECTOR_CLASSIFIER

# %%
from sklearn.svm import SVC

# %%
model=SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred=model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 91.93746922698179

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     22407
#            1       0.00      0.00      0.00      1965
#
#     accuracy                           0.92     24372
#    macro avg       0.46      0.50      0.48     24372
# weighted avg       0.85      0.92      0.88     24372

# %% [markdown]
# # DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(criterion='entropy',max_depth=4)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(x_train,y_train)*100
# Out:
# 91.91662221492759

# %%
model.score(x_test,y_test)*100
# Out:
# 91.93746922698179

# %%
cf=confusion_matrix(y_test,y_pred)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     22407
#            1       0.00      0.00      0.00      1965
#
#     accuracy                           0.92     24372
#    macro avg       0.46      0.50      0.48     24372
# weighted avg       0.85      0.92      0.88     24372

# %% [markdown]
# # ENSEMBLE TECHNIQUES

# %%
#RANDOM FOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier

# %%
rf=RandomForestClassifier(n_estimators=200,criterion='entropy',max_depth=5)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, n_estimators=200)

# %%
rf_pred=rf.predict(x_test)

# %%
rf.score(x_train,y_train)*100
# Out:
# 91.91662221492759

# %%
rf.score(x_test,y_test)*100
# Out:
# 91.93746922698179

# %%
cf=confusion_matrix(y_test,rf_pred)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,rf_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     22407
#            1       0.00      0.00      0.00      1965
#
#     accuracy                           0.92     24372
#    macro avg       0.46      0.50      0.48     24372
# weighted avg       0.85      0.92      0.88     24372

# %%
#BAGGING
from sklearn.ensemble import BaggingClassifier

# %%
bg=BaggingClassifier(n_estimators=50)

# %%
bg.fit(x_train,y_train)
# Out:
# BaggingClassifier(n_estimators=50)

# %%
bg_pred=bg.predict(x_test)

# %%
bg.score(x_test,y_test)
# Out:
# 0.9292220580994583

# %%
bg.score(x_train,y_train)
# Out:
# 0.9991793525091297

# %%
cf=confusion_matrix(y_test,bg_pred)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,bg_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96     22407
#            1       0.94      0.13      0.23      1965
#
#     accuracy                           0.93     24372
#    macro avg       0.94      0.56      0.60     24372
# weighted avg       0.93      0.93      0.90     24372

# %%
#BOOSTING
#ADA BOOST CLASSIFIER
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier()

# %%
ada.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
ada_pred=ada.predict(x_test)

# %%
ada.score(x_train,y_train)
# Out:
# 0.9191559640556399

# %%
ada.score(x_test,y_test)
# Out:
# 0.919333661578861

# %%
cf=confusion_matrix(y_test,ada_pred)

# %%
#confusion_matrix 
plt.figure(figsize=(10,5))
plt.title('Confusion_Matrix',fontsize=25)
sns.heatmap(cf,annot=True,fmt='g',cmap='Blues')
plt.show()

# %%
#classification_report
print(classification_report(y_test,ada_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      1.00      0.96     22407
#            1       0.00      0.00      0.00      1965
#
#     accuracy                           0.92     24372
#    macro avg       0.46      0.50      0.48     24372
# weighted avg       0.85      0.92      0.88     24372

# %%
#gradient boosting classifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc=GradientBoostingClassifier()

# %%
gbc.fit(x_train,y_train)
# Out:
# GradientBoostingClassifier()

# %%
gbc.pred=gbc.predict(x_test)

# %%
gbc.score(x_test,y_test)
# Out:
# 0.9192926308879041

# %%
gbc.score(x_train,y_train)
# Out:
# 0.9192277707110911

# %%
# !pip install xgboost

# %%
#xg boost
import xgboost as xgb

# %%
xgbc=xgb.XGBClassifier()

# %%
xgbc.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
xgbc.pred=xgbc.predict(x_test)

# %%
xgbc.score(x_test,y_test)
# Out:
# 0.91908747743312

# %%
#LIGHT GRAIENT BOOSTING MACHINE (LGBM)

# %%
conda install -c conda-forge lightgbm
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\nagpa\anaconda3
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-22.11.1              |   py39hcbf5309_1         908 KB  conda-forge
#     lightgbm-3.2.1             |   py39hd77b12b_0         754 KB
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     ruamel.yaml-0.17.21        |   py39hb82d6ee_1         169 KB  conda-forge
#     ruamel.yaml.clib-0.2.6     |   py39h2bbff1b_1         101 KB
#     ------------------------------------------------------------
#                                            Total:         1.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   lightgbm           pkgs/main/win-64::lightgbm-3.2.1-py39hd77b12b_0
# ...

# %%
import lightgbm as lgb

# %%
lgbm=lgb.LGBMClassifier()

# %%
lgbm.fit(x_train,y_train)
# Out:
# LGBMClassifier()

# %%
lgbm_pred=lgbm.predict(x_test)

# %%
lgbm.score(x_test,y_test)
# Out:
# 0.9194157229607747
